# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Cropping2D
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np

# Load MNIST data
(x_train, y_train), (x_test, y_test) = mnist.load_data()
input_image_shape = (28, 28, 1)
input_image = x_train[35].reshape(input_image_shape)

# Create the model
model = Sequential()
model.add(Cropping2D(cropping=((0, 0), (0, 5)), input_shape=input_image_shape))
model.summary()

# Perform actual cropping
model_inputs = np.array([input_image])
outputs_cropped = model.predict(model_inputs)

# Get output
outputs_cropped = outputs_cropped[0]

# Visualize input and output
fig, axes = plt.subplots(1, 2)
axes[0].imshow(input_image[:, :, 0]) 
axes[0].set_title('Original image')
axes[1].imshow(outputs_cropped[:, :, 0])
axes[1].set_title('Cropped input')
fig.suptitle(f'Original and cropped input')
fig.set_size_inches(9, 5, forward=True)
plt.show()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# cropping2d_6 (Cropping2D)    (None, 28, 23, 1)         0
# ...
# Total params: 0
# Trainable params: 0
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Cropping2D
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np

# Load MNIST data
(x_train, y_train), (x_test, y_test) = mnist.load_data()
input_image_shape = (28, 28, 1)
input_image = x_train[35].reshape(input_image_shape)


tf.image.crop_to_bounding_box(
    batch, 0, 0, 1, 1
)

# %%
import numpy as np

test1 = [[5,0,2,3],
         [6,8,1,5],
         [0,0,1,0]]

test2 = [[9,2,4,3],
         [6,8,1,5],
         [0,1,0,0]]

test3 = [[5,0,2,3],
         [6,8,1,5],
         [1,0,0,0]]

batch = [test1,test2,test3]

batch = np.array(batch)

# %%
import tensorflow as tf

tf.math.argmax(batch, 2)
# Out:
# <tf.Tensor: shape=(3, 3), dtype=int64, numpy=
# array([[0, 1, 2],
#        [0, 1, 1],
#        [0, 1, 0]], dtype=int64)>

# %%
import numpy as np

test1 = [[[5,2,8,0],[1,8,7,1]],
         [[6,8,2,0],[2,1,9,0]],
         [[2,5,0,0],[4,3,1,0]]]

test2 = [[[5,4,2,0],[1,2,4,0]],
         [[6,1,2,1],[2,0,8,0]],
         [[4,8,4,0],[1,4,9,0]]]

test3 = [[[5,1,9,0],[1,2,7,0]],
         [[6,8,2,0],[2,1,5,0]],
         [[1,9,1,0],[9,7,0,1]]]

test1 = np.array(test1)
test2 = np.array(test2)
test3 = np.array(test3)
test1[:,:,3], test2[:,:,3], test3[:,:,3]
# Out:
# (array([[0, 1],
#         [0, 0],
#         [0, 0]]),
#  array([[0, 0],
#         [1, 0],
#         [0, 0]]),
#  array([[0, 0],
#         [0, 0],
#         [0, 1]]))

# %%
import tensorflow as tf

print(tf.math.reduce_max(tf.math.argmax(test3[:,:,3], 0), 0))
print(tf.math.reduce_max(tf.math.argmax(test3[:,:,3], 1), 0))
# Out:
# tf.Tensor(2, shape=(), dtype=int64)
# tf.Tensor(1, shape=(), dtype=int64)

# %%
inter,a,b
# Out:
# (<tf.Tensor: shape=(3, 3, 2), dtype=int64, numpy=
#  array([[[0, 2],
#          [1, 3],
#          [0, 2]],
#
#         [[0, 2],
#          [0, 2],
#          [0, 0]],
#
#         [[2, 2],
#          [1, 2],
#          [2, 0]]], dtype=int64)>,
#  <tf.Tensor: shape=(3, 2), dtype=int64, numpy=
#  array([[1, 1],
#         [0, 0],
#         [0, 0]], dtype=int64)>,
#  <tf.Tensor: shape=(3, 2), dtype=int64, numpy=
#  array([[1, 3],
#         [0, 2],
#         [2, 2]], dtype=int64)>)

# %%
tf.image.crop_to_bounding_box(
    batch, 0, 0, 1, 1
)
